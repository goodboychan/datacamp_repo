# %% [markdown]
# **Original Source from Datacamp**

# %% [markdown]
# ## Introduction to Seaborn

# %%
# import all modules
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Read in the DataFrame
grant_file = './dataset/schoolimprovement2010grants.csv'
df = pd.read_csv(grant_file)

# %%
# Display pandas histogram
df['Award_Amount'].plot.hist()

# %%
# Display a Seaborn distplot
sns.distplot(df['Award_Amount'])

# %% [markdown]
# ## Using the distribution plot

# %%
# Create a distplot
sns.distplot(df['Award_Amount'],
            kde=False,
            bins=20)

# %%
# Create a distplot of the Award Amount
sns.distplot(df['Award_Amount'],
             hist=False,
             rug=True,
            kde_kws={'shade':True}
            )

# %% [markdown]
# ## Regression Plots in Seaborn

# %%
df = pd.read_csv('./dataset/insurance_premiums.csv')
sns.regplot(x='insurance_losses', y='premiums', data=df)

# %%
sns.lmplot(x='insurance_losses', y='premiums', data=df)

# %%
# Create a regression plot using hue
sns.lmplot(data=df,
           x="insurance_losses",
           y="premiums",
           hue="Region")

# %% [markdown]
# ### Facetting multiple regressions

# %%
# Create a regression plot with multiple rows
sns.lmplot(data=df,
           x="insurance_losses",
           y="premiums",
           row="Region")
